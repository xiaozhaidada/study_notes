# %% [markdown]
# ### 安装环境

# %%
# %pip install torch torchvision 
# %pip install matplotlib
# %pip install torch-pruning
# %pip install onnx onnxscript
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: torch in c:\users\hzc\anaconda3\lib\site-packages (2.13.0)
# Requirement already satisfied: torchvision in c:\users\hzc\anaconda3\lib\site-packages (0.28.0)
# Requirement already satisfied: filelock in c:\users\hzc\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hzc\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\hzc\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hzc\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hzc\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\hzc\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\hzc\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\hzc\anaconda3\lib\site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hzc\anaconda3\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hzc\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hzc\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: matplotlib in c:\users\hzc\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hzc\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hzc\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hzc\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hzc\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\hzc\anaconda3\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hzc\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hzc\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hzc\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hzc\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hzc\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: torch-pruning in c:\users\hzc\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: torch>=2.0 in c:\users\hzc\anaconda3\lib\site-packages (from torch-pruning) (2.13.0)
# Requirement already satisfied: numpy in c:\users\hzc\anaconda3\lib\site-packages (from torch-pruning) (2.3.5)
# Requirement already satisfied: filelock in c:\users\hzc\anaconda3\lib\site-packages (from torch>=2.0->torch-pruning) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hzc\anaconda3\lib\site-packages (from torch>=2.0->torch-pruning) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\hzc\anaconda3\lib\site-packages (from torch>=2.0->torch-pruning) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hzc\anaconda3\lib\site-packages (from torch>=2.0->torch-pruning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hzc\anaconda3\lib\site-packages (from torch>=2.0->torch-pruning) (3.5)
# Requirement already satisfied: jinja2 in c:\users\hzc\anaconda3\lib\site-packages (from torch>=2.0->torch-pruning) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\hzc\anaconda3\lib\site-packages (from torch>=2.0->torch-pruning) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hzc\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=2.0->torch-pruning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hzc\anaconda3\lib\site-packages (from jinja2->torch>=2.0->torch-pruning) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting onnx
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/13/a8/734725bb703c5fabb687f79c79e51249475212b3eb37771ac4a4ac9b487f/onnx-1.22.0-cp312-abi3-win_amd64.whl (17.2 MB)
# Collecting onnxscript
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/dd/bd/a0c8e737b6afda10e42a597787d53d5b66e00268df6f59184701eeae37d9/onnxscript-0.7.1-py3-none-any.whl (721 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\hzc\anaconda3\lib\site-packages (from onnx) (2.3.5)
# Requirement already satisfied: protobuf>=4.25.1 in c:\users\hzc\anaconda3\lib\site-packages (from onnx) (5.29.3)
# Requirement already satisfied: typing_extensions>=4.15.0 in c:\users\hzc\anaconda3\lib\site-packages (from onnx) (4.15.0)
# Collecting ml_dtypes>=0.5.4 (from onnx)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e2/55/4561acefa00fa4bcbfb82ca6a48578b41f372cd7dd7cdd6eb4720abc2e5f/ml_dtypes-0.6.0-cp313-cp313-win_amd64.whl (439 kB)
# Collecting onnx_ir<2,>=0.1.16 (from onnxscript)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/91/cd/6d1637172eb59c7b18ac90ed089d1f599a11fe0e63b4db2d017f3bb38a32/onnx_ir-1.0.0-py3-none-any.whl (185 kB)
# Requirement already satisfied: packaging in c:\users\hzc\anaconda3\lib\site-packages (from onnxscript) (25.0)
# Requirement already satisfied: sympy>=1.13 in c:\users\hzc\anaconda3\lib\site-packages (from onnx_ir<2,>=0.1.16->onnxscript) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hzc\anaconda3\lib\site-packages (from sympy>=1.13->onnx_ir<2,>=0.1.16->onnxscript) (1.3.0)
# Installing collected packages: ml_dtypes, onnx, onnx_ir, onnxscript
#
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    ---------- ----------------------------- 1/4 [onnx]
#    -------------------- ------------------- 2/4 [onnx_ir]
#    -------------------- ------------------- 2/4 [onnx_ir]
#    -------------------- ------------------- 2/4 [onnx_ir]
#    ------------------------------ --------- 3/4 [onnxscript]
#    ------------------------------ --------- 3/4 [onnxscript]
#    ------------------------------ --------- 3/4 [onnxscript]
#    ------------------------------ --------- 3/4 [onnxscript]
#    ------------------------------ --------- 3/4 [onnxscript]
#    ------------------------------ --------- 3/4 [onnxscript]
#    ------------------------------ --------- 3/4 [onnxscript]
#    ------------------------------ --------- 3/4 [onnxscript]
#    ------------------------------ --------- 3/4 [onnxscript]
#    ------------------------------ --------- 3/4 [onnxscript]
#    ---------------------------------------- 4/4 [onnxscript]
#
# Successfully installed ml_dtypes-0.6.0 onnx-1.22.0 onnx_ir-1.0.0 onnxscript-0.7.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 神经网络模型

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout(0.25)
        self.dropout2 = nn.Dropout(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        output = F.log_softmax(x, dim=1)
        return output

model = Model()
print("create model successfully")
# Out:
# create model successfully

# %% [markdown]
# ### 数据集MNIST处理

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

train_dataset = datasets.MNIST(
    root="./dataset",
    train=True,
    download=True,
    transform=transform
)

train_loader = DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True
)

test_dataset = datasets.MNIST(
    root="./dataset",
    train=False,
    download=True,
    transform=transform
)

test_loader = DataLoader(
    test_dataset,
    batch_size=1000,
    shuffle=False
)

print("训练集大小:", len(train_dataset))
print("batch 数量:", len(train_loader))
print("测试集大小:", len(test_dataset))
print("batch 数量:", len(test_loader))
# Out:
# 训练集大小: 60000
# batch 数量: 938
# 测试集大小: 10000
# batch 数量: 10

# %% [markdown]
# ### 模型训练

# %%
import os
import torch.nn.functional as F
from torch.optim import Adadelta

optimizer = Adadelta(
    model.parameters(),
    lr=1.0
)

epochs = 5

for epoch in range(epochs):

    model.train()

    total_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        optimizer.zero_grad()
        output = model(images)
        loss = F.nll_loss(output, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        pred = output.argmax(dim=1)
        correct += (pred == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(train_loader)
    accuracy = 100 * correct / total

    print(
        f"Epoch {epoch + 1}/{epochs}, "
        f"Loss: {avg_loss:.4f}, "
        f"Accuracy: {accuracy:.2f}%"
    )

print("train successfully")

os.makedirs("./model", exist_ok=True)

torch.save(
    model,
    "./model/model.pt"
)

print("save successfully")
# Out:
# Epoch 1/5, Loss: 0.1911, Accuracy: 94.13%
# Epoch 2/5, Loss: 0.0783, Accuracy: 97.78%
# Epoch 3/5, Loss: 0.0600, Accuracy: 98.27%
# Epoch 4/5, Loss: 0.0516, Accuracy: 98.56%
# Epoch 5/5, Loss: 0.0423, Accuracy: 98.75%
# train successfully
# save successfully

# %% [markdown]
# ### 模型测试

# %%
import torch
import torch.nn.functional as F

def test(model):
    model.eval()

    test_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:

            output = model(images)

            loss = F.nll_loss(output, labels)
            test_loss += loss.item()

            predictions = output.argmax(dim=1)

            correct += (predictions == labels).sum().item()
            total += labels.size(0)


    avg_loss = test_loss / len(test_loader)
    accuracy = 100 * correct / total

    print(f"Test Loss: {avg_loss:.4f}")
    print(f"Test Accuracy: {accuracy:.2f}%")

    print("test successfully")

model = torch.load("model/model.pt", weights_only=False)
test(model)
# Out:
# Test Loss: 0.0371
# Test Accuracy: 98.94%
# test successfully

# %% [markdown]
# ### 计算内存大小

# %%
def memory_size(model):
    
    model_memory = 0

    for param in model.parameters():
        model_memory += param.numel() * param.element_size()

    for buffer in model.buffers():
        model_memory += buffer.numel() * buffer.element_size()

    model_memory_mib = model_memory / (1024 ** 2)

    print(f"Model Memory: {model_memory_mib:.2f} MiB")

model = torch.load(
    "model/original_model.pt",
    weights_only=False
)

model = torch.load("model/model.pt")
memory_size(model)
# Out:
# Model Memory: 4.58 MiB

# %% [markdown]
# ### 可视化demo预测结果

# %%
import torch
import matplotlib.pyplot as plt

from PIL import Image
from torchvision import transforms

def visualize_predictions(model):
    plt.figure(figsize=(20, 3))
    demo_inputs = []

    for digit in range(10):
        image = Image.open(f"./demo/{digit}.png").convert("L")
        input_tensor = transform(image)
        demo_inputs.append(input_tensor)

    demo_inputs = torch.stack(demo_inputs)

    model.eval()

    with torch.no_grad():
        predictions = model(demo_inputs).argmax(dim=1)

    for digit in range(10):
        image = Image.open(f"./demo/{digit}.png").convert("L")
        plt.subplot(1, 10, digit + 1)
        plt.imshow(image, cmap="gray")
        plt.title(
            f"digit: {digit}\n"
            f"pred: {predictions[digit].item()}"
        )

        plt.axis("off")

    plt.show()

model = torch.load("model/model.pt")
visualize_predictions(model)

# %% [markdown]
# ### 结构化剪枝

# %%
import torch
import torch.nn as nn
import torch_pruning as tp

model = torch.load("model/model.pt")

x = torch.randn(1, 1, 28, 28)

example_inputs = torch.randn(1, 1, 28, 28)

importance = tp.importance.MagnitudeImportance(p=1)

pruning_ratio = 0.3

ignored_layers = [model.fc2]

pruner = tp.pruner.MagnitudePruner(
    model,
    example_inputs,
    importance=importance,
    pruning_ratio=pruning_ratio,
    ignored_layers=ignored_layers
)

# 执行结构化剪枝
pruner.step()

print(model)

x = torch.randn(1, 1, 28, 28)

print("structured pruning successfully")
# Out:
# Model(
#   (conv1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(4, 9, kernel_size=(3, 3), stride=(1, 1))
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=1296, out_features=18, bias=True)
#   (fc2): Linear(in_features=18, out_features=10, bias=True)
# )
# structured pruning successfully

# %%
test(model)
memory_size(model)
visualize_predictions(model)
# Out:
# Test Loss: 2.2918
# Test Accuracy: 12.18%
# test successfully
# Model Memory: 0.09 MiB

# %% [markdown]
# ### Fine-Tune 微调

# %%
import torch
import torch.nn.functional as F

# 微调优化器
optimizer = torch.optim.Adadelta(
    model.parameters(),
    lr=1e-3
)

fine_tune_epochs = 5

for epoch in range(fine_tune_epochs):

    model.train()

    total_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:

        optimizer.zero_grad()

        output = model(images)

        loss = F.nll_loss(output, labels)

        loss.backward()

        optimizer.step()

        total_loss += loss.item()

        predictions = output.argmax(dim=1)

        correct += (predictions == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(train_loader)
    accuracy = 100 * correct / total

    print(
        f"Fine-tune Epoch {epoch + 1}/{fine_tune_epochs}, "
        f"Loss: {avg_loss:.4f}, "
        f"Accuracy: {accuracy:.2f}%"
    )

print("tine-tune successfully")
# Out:
# Fine-tune Epoch 1/5, Loss: 0.2040, Accuracy: 96.34%
# Fine-tune Epoch 2/5, Loss: 0.0923, Accuracy: 97.86%
# Fine-tune Epoch 3/5, Loss: 0.0627, Accuracy: 98.34%
# Fine-tune Epoch 4/5, Loss: 0.0518, Accuracy: 98.52%
# Fine-tune Epoch 5/5, Loss: 0.0478, Accuracy: 98.58%

# %%
test(model)
memory_size(model)
visualize_predictions(model)
# Out:
# Test Loss: 0.0362
# Test Accuracy: 99.08%
# test successfully
# Model Memory: 2.19 MiB

# %% [markdown]
# ### 导出为onnx

# %%
import torch

model.eval()

dummy_input = torch.randn(1, 1, 28, 28)

torch.onnx.export(
    model,
    dummy_input,
    "model/model_pruned.onnx",

    input_names=["input"],
    output_names=["output"],

    opset_version=18,
)

print("ONNX export successfully")
# Out:
# [torch.onnx] Obtain model graph for `Model([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `Model([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decompositions...
# [torch.onnx] Run decompositions... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# [torch.onnx] Optimize the ONNX graph...
# [torch.onnx] Optimize the ONNX graph... ✅
# ONNX export successfully
# C:\Users\Hzc\anaconda3\Lib\copyreg.py:99: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)

# %% [markdown]
# ### 检测onnx文件

# %%
import onnx

onnx_model = onnx.load("./model/model_pruned.onnx")

onnx.checker.check_model(onnx_model)

print("ONNX model check passed")
# Out:
# ONNX model check passed
