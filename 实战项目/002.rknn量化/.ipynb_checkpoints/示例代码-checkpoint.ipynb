# %% [markdown]
# ## rknn_toolkit2 适配 python3.10, 所以在运行前请更换 kernel

# %%
# %pip install torch==2.4.0 torchvision==0.19.0 -i https://pypi.tuna.tsinghua.edu.cn/simple
# %pip install setuptools==80.9.0 -i https://pypi.tuna.tsinghua.edu.cn/simple
# %pip install onnx==1.18 onnxruntime==1.18 -i https://pypi.tuna.tsinghua.edu.cn/simple
# %pip install rknn_toolkit2 -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ### 数据集 MNIST 处理

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

test_dataset = datasets.MNIST(
    root="./dataset",
    train=False,
    download=True,
    transform=transform
)

test_loader = DataLoader(
    test_dataset,
    batch_size=1000,
    shuffle=False
)

print("测试集大小:", len(test_dataset))
print("batch 数量:", len(test_loader))

# %% [markdown]
# ### ONNX 准确率

# %%
import numpy as np
import onnxruntime as ort

def onnxAccuracy(model):
    session = ort.InferenceSession(
        model,
        providers=["CPUExecutionProvider"]
    )

    input_name = session.get_inputs()[0].name
    output_name = session.get_outputs()[0].name

    correct = 0
    total = 0

    for images, labels in test_loader:
        images = images.numpy().astype(np.float32)
        outputs = session.run(
            [output_name],
            {input_name: images}
        )[0]
        predictions = np.argmax(outputs, axis=1)
        labels = labels.numpy()
        correct += np.sum(predictions == labels)
        total += labels.shape[0]

    accuracy = correct / total * 100

    print(f"ONNX Accuracy: {accuracy:.2f}%")

onnxAccuracy("./model/model_pruned_fp32.onnx")

# %% [markdown]
# ### 校准数据集

# %%
import os
from torchvision import datasets

DATASET_DIR = "./dataset"
CALIB_DIR = "./calibration"
DATASET_TXT = "./calibration.txt"

os.makedirs(CALIB_DIR, exist_ok=True)

dataset = datasets.MNIST(
    root=DATASET_DIR,
    train=True,
    download=False
)

num_calib = 200

with open(DATASET_TXT, "w") as f:
    for i in range(num_calib):
        img, label = dataset[i]

        path = os.path.join(
            CALIB_DIR,
            f"{i:05d}.png"
        )

        img.save(path)

        # dataset.txt 每行一张图片
        f.write(path + "\n")

print("校准数据生成完成")
print("图片数量:", num_calib)

# %% [markdown]
# ### INT8 PTQ + 计算准确率

# %%
from rknn.api import RKNN
from torchvision import datasets
import numpy as np

ONNX_PATH = "./model/model_pruned_fp32.onnx"
RKNN_PATH = "./model/model_pruned_int8.rknn"
CALIBRATION_PATH = "./calibration.txt"

rknn = RKNN(verbose=True)

ret = rknn.config(
    target_platform="rk3588",
    mean_values=[[0.1307*255]],
    std_values=[[0.3081*255]],
)
if ret != 0:
    print("config failed:", ret)
    exit(ret)

ret = rknn.load_onnx(
    model=ONNX_PATH,
    inputs=["input"],
    input_size_list=[[1, 1, 28, 28]],
)
if ret != 0:
    print("load_onnx failed:", ret)
    exit(ret)

ret = rknn.build(
    do_quantization=True,
    dataset=CALIBRATION_PATH,
)
if ret != 0:
    print("build failed:", ret)
    exit(ret)

ret = rknn.export_rknn(
    RKNN_PATH,
)
if ret != 0:
    print("export_rknn failed:", ret)
    exit(ret)

print("\n########################")
print("\nINT8 PTQ successfully")
print("\n########################")

##################
# RKNN 准确率
##################

test_dataset = datasets.MNIST(
    root="./dataset",
    train=False,
    download=True,
)

ret = rknn.init_runtime()
if ret != 0:
    print("init_runtime failed:", ret)
    exit(ret)

correct = 0
total = len(test_dataset)

for i in range(total):
    image, label = test_dataset[i]
    image = np.asarray(image, dtype=np.uint8)[None, None, :, :]
    
    outputs = rknn.inference(
        inputs=[image],
        data_format=["nchw"],
    )
    
    if outputs is None:
        print(f"Inference failed at sample {i}")
        
    output = np.asarray(outputs[0]).reshape(-1)
    pred = np.argmax(output)

    if pred == label:
        correct += 1

accuracy = correct / total * 100

print("\n########################")
print(f"\nRKNN Accuracy: {accuracy:.2f}%")
print("\n########################")

rknn.release()
# Out:
# I rknn-toolkit2 version: 2.3.2
# W load_onnx: If you don't need to crop the model, don't set 'inputs'/'input_size_list'/'outputs'!
# I Loading : 100%|██████████████████████████████████████████████████| 9/9 [00:00<00:00, 11565.18it/s]
# D base_optimize ...
# D base_optimize done.
# D
# D fold_constant ...
# D fold_constant done.
# D fold_constant remove nodes = ['node_Concat_4', 'node_Shape_0']
# D Fixed the shape information of some tensor!
# D
# D correct_ops ...
# D correct_ops done.
# D
# D fuse_ops ...
# D fuse_ops results:
# D     convert_gemm_by_exmatmul: remove node = ['node_linear'], add node = ['view_tp', 'view_tp_rs', 'node_linear#1', 'linear_mm_tp', 'linear_mm_tp_rs']
# D     unsqueeze_to_4d_relu: remove node = [], add node = ['linear_rs', 'relu_2-rs']
# D     convert_gemm_by_exmatmul: remove node = ['node_linear_1'], add node = ['relu_2_tp', 'relu_2_tp_rs', 'node_linear_1#1', 'linear_1_mm_tp', 'linear_1_mm_tp_rs']
# D     unsqueeze_to_4d_logsoftmax: remove node = [], add node = ['linear_1_rs', 'output-rs']
# D     unsqueeze_to_4d_transpose: remove node = [], add node = ['view_rs', 'view_tp-rs']
# D     unsqueeze_to_4d_transpose: remove node = [], add node = ['relu_2_rs', 'relu_2_tp-rs']
# D     fuse_two_reshape: remove node = ['node_view']
# D     fuse_transpose_reshape: remove node = ['view_tp', 'linear_mm_tp']
# D     bypass_two_reshape: remove node = ['relu_2_rs', 'relu_2-rs']
# D     fuse_transpose_reshape: remove node = ['relu_2_tp', 'linear_1_mm_tp']
# D     fuse_two_reshape: remove node = ['view_rs']
# D     bypass_two_reshape: remove node = ['linear_rs', 'linear_mm_tp_rs', 'relu_2_tp_rs', 'relu_2_tp-rs', 'linear_1_rs', 'linear_1_mm_tp_rs']
# D     fuse_two_reshape: remove node = ['view_tp-rs']
# D     convert_exmatmul_to_conv: remove node = ['node_linear#1'], add node = ['node_linear#2']
# D     convert_exmatmul_to_conv: remove node = ['node_linear_1#1'], add node = ['node_linear_1#2']
# D     fold_constant ...
# D     fold_constant done.
# D fuse_ops done.
# D
# D sparse_weight ...
# D sparse_weight done.
# D
# I GraphPreparing : 100%|██████████████████████████████████████████| 11/11 [00:00<00:00, 6611.83it/s]
# I Quantizating : 100%|█████████████████████████████████████████████| 11/11 [00:00<00:00, 123.73it/s]
# D
# D quant_optimizer ...
# D quant_optimizer results:
# D     adjust_relu: ['node_relu_2', 'node_relu_1', 'node_relu']
# D quant_optimizer done.
# D
# W build: The default input dtype of 'input' is changed from 'float32' to 'int8' in rknn model for performance!
#                        Please take care of this change when deploy rknn model with Runtime API!
# W build: The default output dtype of 'output' is changed from 'float32' to 'int8' in rknn model for performance!
#                       Please take care of this change when deploy rknn model with Runtime API!
# I rknn building ...
# I rknn building done.
# I Target is None, use simulator!
# ----------------------------+---------------------------------
# D RKNN: [19:28:24.748] ID  User     Tensor        DataType  OrigShape     |     [Start       End)       Size
# D RKNN: [19:28:24.748] ---------------------------------------------------+---------------------------------
# D RKNN: [19:28:24.748] 1   ConvRelu conv1.weight  INT8      (9,1,3,3)     | 0x00000000 0x000005a0 0x000005a0
# D RKNN: [19:28:24.748] 1   ConvRelu conv1.bias    INT32     (9)           | 0x000005c0 0x000006c0 0x00000100
# D RKNN: [19:28:24.748] 2   ConvRelu conv2.weight  INT8      (19,9,3,3)    | 0x000006c0 0x00001200 0x00000b40
# D RKNN: [19:28:24.748] 2   ConvRelu conv2.bias    INT32     (19)          | 0x00001200 0x00001300 0x00000100
# D RKNN: [19:28:24.748] 4   Reshape  view_tp_rs_i1 INT64     (4)           | 0x0001ae40 0x0001ae60 0x00000020
# D RKNN: [19:28:24.748] 5   ConvRelu fc1.weight    INT8      (38,2736,1,1) | 0x00001300 0x0001a920 0x00019620
# D RKNN: [19:28:24.748] 5   ConvRelu fc1.bias      INT32     (38)          | 0x0001a940 0x0001ab40 0x00000200
# D RKNN: [19:28:24.748] 6   Conv     fc2.weight    INT8      (10,38,1,1)   | 0x0001ab40 0x0001ad20 0x000001e0
# D RKNN: [19:28:24.748] 6   Conv     fc2.bias      INT32     (10)          | 0x0001ad40 0x0001ae40 0x00000100
# D RKNN: [19:28:24.748] 8   Reshape  output-rs_i1  INT64     (2)           | 0x0001ae80 0x0001ae90 0x00000010
# D RKNN: [19:28:24.748] ---------------------------------------------------+---------------------------------
# D RKNN: [19:28:24.748] ----------------------------------------
# D RKNN: [19:28:24.748] Total Internal Memory Size: 40KB
# D RKNN: [19:28:24.748] Total Weight Memory Size: 109.688KB
# D RKNN: [19:28:24.748] ----------------------------------------
# D RKNN: [19:28:24.748] <<<<<<<< end: rknn::RKNNMemStatisticsPass
# I RKNN: [19:28:49.123] compress = 0, conv_eltwise_activation_fuse = 1, global_fuse = 1, multi-core-model-mode = 7, output_optimize = 1, layout_match = 1, enable_argb_group = 0, op_group_sram_opt = 0, enable_flash_attention = 0, op_group_nbuf_opt = 0, safe_fuse = 0
# I RKNN: librknnc version: 2.3.2 (e045de294f@2025-04-07T19:48:25)
# D RKNN: [19:28:49.124] RKNN is invoked
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNExtractCustomOpAttrs
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNExtractCustomOpAttrs
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNSetOpTargetPass
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNSetOpTargetPass
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNBindNorm
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNBindNorm
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNEliminateQATDataConvert
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNEliminateQATDataConvert
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNConvStrideFixPass
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNConvStrideFixPass
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNTileGroupConv
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNTileGroupConv
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNAddConvBias
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNAddConvBias
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNTileChannel
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNTileChannel
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNDuplicateWeightPass
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNDuplicateWeightPass
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNInitRNNConst
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNInitRNNConst
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNPerChannelPrep
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNPerChannelPrep
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNBnQuant
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNBnQuant
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNFuseOptimizerPass
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNFuseOptimizerPass
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNTurnAutoPad
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNTurnAutoPad
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNInitCastConst
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNInitCastConst
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNMultiSurfacePass
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNMultiSurfacePass
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNReplaceConstantTensorPass
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNReplaceConstantTensorPass
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNSubgraphManager
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNSubgraphManager
# D RKNN: [19:28:49.127] >>>>>> start: OpEmit
# D RKNN: [19:28:49.127] <<<<<<<< end: OpEmit
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNAddFirstConv
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNAddFirstConv
# D RKNN: [19:28:49.127] >>>>>> start: rknn::RKNNTilingPass
# D RKNN: [19:28:49.127] <<<<<<<< end: rknn::RKNNTilingPass
# D RKNN: [19:28:49.128] >>>>>> start: rknn::RKNNLayoutMatchPass
# D RKNN: [19:28:49.128] <<<<<<<< end: rknn::RKNNLayoutMatchPass
# D RKNN: [19:28:49.128] >>>>>> start: rknn::RKNNAddSecondaryNode
# D RKNN: [19:28:49.128] <<<<<<<< end: rknn::RKNNAddSecondaryNode
# D RKNN: [19:28:49.128] >>>>>> start: rknn::RKNNAllocateConvCachePass
# D RKNN: [19:28:49.128] <<<<<<<< end: rknn::RKNNAllocateConvCachePass
# D RKNN: [19:28:49.128] >>>>>> start: OpEmit
# D RKNN: [19:28:49.128] finish initComputeZoneMapByStepsVector
# D RKNN: [19:28:49.128] finish initComputeZoneMapByStepsVector
# D RKNN: [19:28:49.128] finish initComputeZoneMapByStepsVector
# D RKNN: [19:28:49.128] finish initComputeZoneMapByStepsVector
# D RKNN: [19:28:49.128] <<<<<<<< end: OpEmit
# D RKNN: [19:28:49.128] >>>>>> start: rknn::RKNNSubGraphMemoryPlanPass
# D RKNN: [19:28:49.128] <<<<<<<< end: rknn::RKNNSubGraphMemoryPlanPass
# D RKNN: [19:28:49.128] >>>>>> start: rknn::RKNNProfileAnalysisPass
# D RKNN: [19:28:49.128] <<<<<<<< end: rknn::RKNNProfileAnalysisPass
# D RKNN: [19:28:49.128] >>>>>> start: rknn::RKNNOperatorIdGenPass
# D RKNN: [19:28:49.128] <<<<<<<< end: rknn::RKNNOperatorIdGenPass
# D RKNN: [19:28:49.128] >>>>>> start: rknn::RKNNWeightTransposePass
# W RKNN: [19:28:49.132] Warning: Tensor view_tp_rs_i1 need parameter qtype, type is set to float16 by default!
# W RKNN: [19:28:49.132] Warning: Tensor view_tp_rs_i1 need parameter qtype, type is set to float16 by default!
# W RKNN: [19:28:49.132] Warning: Tensor output-rs_i1 need parameter qtype, type is set to float16 by default!
# W RKNN: [19:28:49.132] Warning: Tensor output-rs_i1 need parameter qtype, type is set to float16 by default!
# D RKNN: [19:28:49.132] <<<<<<<< end: rknn::RKNNWeightTransposePass
# D RKNN: [19:28:49.132] >>>>>> start: rknn::RKNNCPUWeightTransposePass
# D RKNN: [19:28:49.132] <<<<<<<< end: rknn::RKNNCPUWeightTransposePass
# D RKNN: [19:28:49.132] >>>>>> start: rknn::RKNNModelBuildPass
# D RKNN: [19:28:49.133] <<<<<<<< end: rknn::RKNNModelBuildPass
# D RKNN: [19:28:49.133] >>>>>> start: rknn::RKNNModelRegCmdbuildPass
# D RKNN: [19:28:49.134] --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# D RKNN: [19:28:49.134]                                                         Network Layer Information Table
# D RKNN: [19:28:49.134] --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# D RKNN: [19:28:49.134] ID   OpType             DataType Target InputShape                               OutputShape            Cycles(DDR/NPU/Total)    RW(KB)       FullName
# D RKNN: [19:28:49.134] --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# D RKNN: [19:28:49.134] 0    InputOperator      INT8     NPU    \                                        (1,1,28,28)            0/0/0                    0            InputOperator:input
# D RKNN: [19:28:49.134] 1    ConvRelu           INT8     NPU    (1,1,28,28),(9,1,3,3),(9)                (1,9,26,26)            563/6192/6192            2            Conv:node_conv2d
# D RKNN: [19:28:49.134] 2    ConvRelu           INT8     NPU    (1,9,26,26),(19,9,3,3),(19)              (1,19,24,24)           1370/5184/5184           13           Conv:node_conv2d_1
# D RKNN: [19:28:49.134] 3    MaxPool            INT8     NPU    (1,19,24,24)                             (1,19,12,12)           0/0/0                    18           MaxPool:node_max_pool2d
# D RKNN: [19:28:49.134] 4    Reshape            INT8     NPU    (1,19,12,12),(4)                         (1,2736,1,1)           0/0/0                    4            Reshape:view_tp_rs
# D RKNN: [19:28:49.134] 5    ConvRelu           INT8     NPU    (1,2736,1,1),(38,2736,1,1),(38)          (1,38,1,1)             4535/2752/4535           104          Conv:node_linear#2
# D RKNN: [19:28:49.134] 6    Conv               INT8     NPU    (1,38,1,1),(10,38,1,1),(10)              (1,10,1,1)             30/64/64                 0            Conv:node_linear_1#2
# D RKNN: [19:28:49.134] 7    LogSoftmax         INT8     CPU    (1,10,1,1)                               (1,10,1,1)             0/0/0                    0            LogSoftmax:node_log_softmax
# D RKNN: [19:28:49.134] 8    Reshape            INT8     NPU    (1,10,1,1),(2)                           (1,10)                 0/0/0                    0            Reshape:output-rs
# D RKNN: [19:28:49.134] 9    OutputOperator     INT8     CPU    (1,10)                                   \                      0/0/0                    0            OutputOperator:output
# D RKNN: [19:28:49.134] --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# D RKNN: [19:28:49.134] <<<<<<<< end: rknn::RKNNModelRegCmdbuildPass
# D RKNN: [19:28:49.134] >>>>>> start: rknn::RKNNModelExportPass
# D RKNN: [19:28:49.134] Export RKNN model to /tmp/tmpkhamfm5m/check.rknn
# D RKNN: [19:28:49.134] <<<<<<<< end: rknn::RKNNModelExportPass
# D RKNN: [19:28:49.134] >>>>>> start: rknn::RKNNMemStatisticsPass
# D RKNN: [19:28:49.134] -------------------------------------------------------------------------------------------------------------------------------
# D RKNN: [19:28:49.134]                                           Feature Tensor Information Table
# D RKNN: [19:28:49.134] ---------------------------------------------------------------------------------------------+---------------------------------
# D RKNN: [19:28:49.134] ID  User           Tensor                 DataType  DataFormat   OrigShape    NativeShape    |     [Start       End)       Size
# D RKNN: [19:28:49.134] ---------------------------------------------------------------------------------------------+---------------------------------
# D RKNN: [19:28:49.134] 1   ConvRelu       input                  INT8      NC1HWC2      (1,1,28,28)  (1,1,28,28,1)  | 0x00000000 0x00000380 0x00000380
# D RKNN: [19:28:49.134] 2   ConvRelu       relu                   INT8      NC1HWC2      (1,9,26,26)  (1,2,26,26,16) | 0x00000380 0x00005800 0x00005480
# D RKNN: [19:28:49.134] 3   MaxPool        relu_1                 INT8      NC1HWC2      (1,19,24,24) (1,2,24,24,16) | 0x00005800*0x0000a000 0x00004800
# D RKNN: [19:28:49.134] 4   Reshape        max_pool2d             INT8      NC1HWC2      (1,19,12,12) (1,2,12,12,16) | 0x00000000 0x00001200 0x00001200
# D RKNN: [19:28:49.134] 4   Reshape        max_pool2d_exSecondary INT8      NC1HWC2      (1,19,12,12) (1,4,12,12,16) | 0x00001200 0x00003600 0x00002400
# D RKNN: [19:28:49.134] 5   ConvRelu       view_tp_rs             INT8      NC1HWC2      (1,2736,1,1) (1,172,1,1,16) | 0x00003600 0x000040c0 0x00000ac0
# D RKNN: [19:28:49.134] 6   Conv           relu_2-rs              INT8      NC1HWC2      (1,38,1,1)   (1,4,1,1,16)   | 0x00000000 0x00000040 0x00000040
# D RKNN: [19:28:49.134] 7   LogSoftmax     linear_1_mm            INT8      NC1HWC2      (1,10,1,1)   (1,2,1,1,16)   | 0x00000040 0x00000060 0x00000020
# D RKNN: [19:28:49.134] 8   Reshape        output-rs              INT8      UNDEFINED    (1,10,1,1)   (1,10,1,1)     | 0x00000000 0x00000010 0x00000010
# D RKNN: [19:28:49.134] 8   Reshape        output-rs_exSecondary  INT8      NC1HWC2      (1,10,1,1)   (1,4,
# ########################
#
# INT8 PTQ successfully
#
# ########################
# I GraphPreparing : 100%|██████████████████████████████████████████| 13/13 [00:00<00:00, 9881.47it/s]
# I SessionPreparing : 100%|████████████████████████████████████████| 13/13 [00:00<00:00, 2681.38it/s]
# ########################
#
# RKNN Accuracy: 97.29%
#
# ########################

# %% [markdown]
# ### 计算内存大小

# %%
import os

path = "./model/model_pruned_int8.rknn"

size_bytes = os.path.getsize(path)
size_mb = size_bytes / 1024 / 1024

print(f"RKNN模型大小: {size_mb:.2f} MB")
